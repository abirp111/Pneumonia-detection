# %% [markdown]
# # Project: Detection of Pneumonia from Chest X-ray Images Using Convolutional Neural Networks and Primary Treatment Suggestion

# %% [markdown]
# ## 1. Installing Python Libraries

# %%
# !pip install numpy==1.26.4 opencv-python==4.11.0.86 tensorflow tensorflow-gpu==2.10.0 matplotlib scikit-learn seaborn
# Out:
# Requirement already satisfied: numpy==1.26.4 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (1.26.4)
# Requirement already satisfied: opencv-python==4.11.0.86 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (4.11.0.86)
# Requirement already satisfied: tensorflow in c:\users\abir\anaconda3\envs\test1\lib\site-packages (2.10.0)
# Requirement already satisfied: tensorflow-gpu==2.10.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (2.10.0)
# Requirement already satisfied: matplotlib in c:\users\abir\anaconda3\envs\test1\lib\site-packages (3.10.5)
# Requirement already satisfied: scikit-learn in c:\users\abir\anaconda3\envs\test1\lib\site-packages (1.7.1)
# Requirement already satisfied: seaborn in c:\users\abir\anaconda3\envs\test1\lib\site-packages (0.13.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (3.14.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (25.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (1.17.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (1.74.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorflow-gpu==2.10.0) (2.10.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (3.8.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (3.1.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (0.45.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (0.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (3.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\abir\anaconda3\envs\test1\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow-gpu==2.10.0) (3.0.2)

# %% [markdown]
# ## 2. Setting Up GPU

# %%
#Importing Tensorflow library
import tensorflow as tf

# %%
# Preventing Out of Memory error for the GPU
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ## 3. Pipelining Dataset

# %%
#Importing some basic libraries for preparation & computation of the dataset
import numpy as np
import os
import cv2
from matplotlib import pyplot as plt

# %%
#Building the dataset pipeline
dataset = tf.keras.utils.image_dataset_from_directory('dataset', batch_size=32, image_size=(256, 256))
# Out:
# Found 5856 files belonging to 2 classes.

# %%
#Accessing dataset pipeline as a loop by converting as Numpy iterator
data_itr = dataset.as_numpy_iterator()
#Accessing single batch from dataset pipeline
#Grab another batch | A batch contains images and labels
selected_batch = data_itr.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(selected_batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(selected_batch[1][idx])

# %% [markdown]
# ## 4. Pre-processing & Splitting Dataset Partitions

# %%
#Scaling Dataset
dataset = dataset.map(lambda x,y: (x/255, y)) #Going through images transformation to make the data access process faster by reducing size. x is images, y is labels

# %%
#Splitting Dataset to train, val and test
train_dataset_size = int(len(dataset)*.7)
val_dataset_size = int(len(dataset)*.2)
test_dataset_size = int(len(dataset)*.1)

#Preping and assigning train, val, test data to seperate instances
train = dataset.take(train_dataset_size)
val = dataset.skip(train_dataset_size).take(val_dataset_size)
test = dataset.skip(train_dataset_size + val_dataset_size).take(test_dataset_size)

# %% [markdown]
# ## 5. Setting Up The Deep Learning Model

# %%
from tensorflow.keras.models import Sequential #Sequential groups a linear stack of layers into a Model which is from Keras library used for 1 single input and 1 single output model building
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras import regularizers

# %%
model = Sequential()

# %%
#Convolutional layer 1
#MobileNetV3Small applies 16 filters
model.add(Conv2D(16, (3,3), 1, activation='relu', padding='same', kernel_regularizer='l2', input_shape=(256,256,3))) #With 16 filters, each filter got 3x3 pixel shape and it moves as 1 pixel
model.add(BatchNormalization())
model.add(MaxPooling2D())
#Convolutional layer 2
model.add(Conv2D(32, (3,3), 1, activation='relu', padding='same', kernel_regularizer='l2'))
model.add(MaxPooling2D())
#Convolutional layer 3
model.add(Conv2D(16, (3,3), 1, activation='relu', padding='same', kernel_regularizer='l2'))
model.add(MaxPooling2D())

#Flattening the model to one dimetional condensed layer
model.add(Flatten())
model.add(Dropout(0.3))

#Fully connected layers
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

#Compiling the model with Adam optimizer
#Specifing loss for binary classification problem
#Applying Accuracy matrix to track accuracy
model.compile('adam', metrics=['accuracy'], loss=tf.losses.BinaryCrossentropy())
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 256, 256, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256, 256, 16)        │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 128, 128, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 128, 128, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 64, 64, 16)          │           4,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 32, 32, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 16384)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16384)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       4,194,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,204,593 (16.04 MB)
#  Trainable params: 4,204,561 (16.04 MB)
#  Non-trainable params: 32 (128.00 B)

# %% [markdown]
# ## 6. Train

# %%
#Setting up log
callback = tf.keras.callbacks.TensorBoard(log_dir='logs')
#Start training 400 times or epochs
history = model.fit(train, epochs=400, validation_data=val, callbacks=[callback])
# Out:
# Epoch 1/5
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9111 - loss: 0.6753 - val_accuracy: 0.9262 - val_loss: 0.7390
# Epoch 2/5
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9558 - loss: 0.4082 - val_accuracy: 0.9236 - val_loss: 0.5332
# Epoch 3/5
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.9607 - loss: 0.3264 - val_accuracy: 0.8854 - val_loss: 0.4441
# Epoch 4/5
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 253s 2s/step - accuracy: 0.9666 - loss: 0.2640 - val_accuracy: 0.9566 - val_loss: 0.3216
# Epoch 5/5
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 213s 2s/step - accuracy: 0.9736 - loss: 0.2128 - val_accuracy: 0.9566 - val_loss: 0.2481

# %% [markdown]
# ## 7. Plot Performance

# %%
fig = plt.figure()
plt.plot(history.history['loss'], label='loss', color='red')
plt.plot(history.history['val_loss'], label='val_loss', color='yellow')
fig.suptitle('Loss', fontsize=18)
plt.legend(loc="upper right")
plt.savefig('loss.jpg')
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['accuracy'], label='accuracy', color='green')
plt.plot(history.history['val_accuracy'], label='val_accuracy', color='purple')
fig.suptitle('Accuracy', fontsize=18)
plt.legend(loc="lower right")
plt.savefig('accuracy.jpg')
plt.show()

# %% [markdown]
# ## 8. Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy, TruePositives, TrueNegatives, FalsePositives, FalseNegatives
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
# Calculating Precision, Recall, Binary Accuracy & Confusion Matrix
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

arr_y = np.empty(0)
arr_y_pred = np.empty(0)

for selected_batch in test.as_numpy_iterator():
    x, y = selected_batch
    y_pred = model.predict(x)
    
    arr_y = np.append(arr_y, y)
    arr_y_pred = np.append(arr_y_pred, y_pred)
    
    pre.update_state(y, y_pred)
    re.update_state(y, y_pred)
    acc.update_state(y, y_pred)
# Out:
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
# Calculating F1-Score metrics
f1_score = 2 * (pre.result().numpy() * re.result().numpy()) / (pre.result().numpy()+re.result().numpy())
print("Precision:", pre.result().numpy(), ", Recall:", re.result().numpy(), ", Binary Accuracy: ", acc.result().numpy(), ", F1-Score: ", f1_score)
# Out:
# Precision: 0.97417843 , Recall: 0.97189695 , Binary Acc.:  0.9600694 , F1-Score:  0.9730363450501027

# %%
# Plotting the above metrics
labels = [f'Precision: {round(pre.result().numpy()*100, 2)}%', f'Recall: {round(re.result().numpy()*100, 2)}%', f'Binary Acc.: {round(acc.result().numpy()*100, 2)}%', f'F1-Score: {round(f1_score*100, 2)}%']
values = [pre.result().numpy()*100, re.result().numpy()*100, acc.result().numpy()*100, f1_score*100]
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects = ax.bar(x-width/2, values, width, label="Metrics")
ax.set_xticks(x, labels)
plt.title("Metrics: Precision, Recall, Binary Accuracy & F1-Score")
plt.savefig('metrics.jpg')
plt.show()

# %%
new_y_pred = np.empty(0)

# Going through the predictions and since the Confusion Matrix function cannot take binary and continuous values together, so setting up the threshold to 0.5
# If the predicted value is greater than or equal to 0.5 then it would result as Pnumonia which is class 1, otherwise Normal which is class 0 
for pred_val in arr_y_pred:
    if pred_val >= 0.5:
        new_y_pred = np.append(new_y_pred, 1)
    else:
        new_y_pred = np.append(new_y_pred, 0)

# %%
# Confusion Matrix | 0 = Normal, 1 = Pneumonia
cm = confusion_matrix(y_true=arr_y, y_pred=new_y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title("Confusion Matrix (0-Normal, 1-Pneumonia)")
plt.savefig('confusion_matrix.jpg')
plt.show()

# %% [markdown]
# ## 9. Test

# %%
import webbrowser
import winsound

# %%
img = cv2.imread(os.path.join('2.jpg'))
plt.imshow(img)
plt.show()

# %%
resized_img = tf.image.resize(img, (256,256))
plt.imshow(resized_img.numpy().astype(int))
plt.show()

# %%
y_pred = model.predict(np.expand_dims(resized_img/255, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step

# %%
print('Predicted value:', y_pred[0][0])
if y_pred > 0.5: 
    print('WARNING! Pneumonia detected!!!')
    url = "https://www.mayoclinic.org/diseases-conditions/pneumonia/diagnosis-treatment/drc-20354210#ul_0b6cac6e-7ca6-4870-b363-d8ee70a56c83"
    webbrowser.open(url, new=0, autoraise=True)
    duration = 1000  # milliseconds
    freq = 440  # Hz
    winsound.Beep(freq, duration)
else:
    print('This X-Ray is Normal.')
# Out:
# Predicted value: 0.9996076
# WARNING! Pneumonia detected!!!

# %% [markdown]
# ## 10. Save the Custom Model

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('output','pneumonia_detector.h5'))

# %%
new_model = load_model(os.path.join('output','pneumonia_detector.h5'))

# %%
new_model.predict(np.expand_dims(resized_img/255, 0))
